# %%
import openpyxl
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from helpers import keep_top_software
# %matplotlib inline

# %%
df = pd.read_excel('data/orig_df.xlsx', engine='openpyxl')

# %%
df = df.set_index('name')

# %%
del df['type']
del df['field']

# %%
index = df.index
cols = df.columns
df
# Out:
#                             search  import  expertaddition  tiabscreen  \
# name
# 3d-NMA                           0       0               0           0
# Abstrackr                        0       1               0           1
# Cadima                           0       1               0           1
# Colandr                          1       1               1           1
# COVID-NMA                        0       0               0           0
# Covidence                        0       1               1           1
# Data Abstraction Assistant       0       1               0           0
# DistillerSR                      1       1               1           1
# EPPI-Reviewer Web                1       1               1           1
# EROS                             0       1               0           1
# JBI SUMARI                       1       1               1           1
# LitStream                        0       1               1           1
# ...

# %%
figsize=(20, 10) 
res = sns.heatmap(df, cmap='magma_r',xticklabels=True, yticklabels=True)
plt.ylabel('Software')
# Out:
# Text(26.49999999999999, 0.5, 'Software')

# %%
plt.savefig('heatmap.png')

# %%
plt.figure(figsize=(16,9))
 
ax = sns.heatmap(df, cmap='magma_r',xticklabels=True, yticklabels=True)
ax.set(title="Systematic Review Software",
      xlabel="feature", ylabel='software')
# Out:
# [Text(0.5, 1.0, 'Systematic Review Software'),
#  Text(0.5, 47.40625, 'feature'),
#  Text(110.40624999999999, 0.5, 'software')]

# %%
#res = sns.heatmap(df, cmap='magma_r',xticklabels=True, yticklabels=True, linewidths=0.5, annot=True)

# %%
ax = sns.heatmap(df, cmap='magma_r',xticklabels=True, yticklabels=True)
 
ax.set(title="Systematic Review Software",
      xlabel="Feature",
      ylabel="Software",)
 
sns.set(font_scale=2) # set fontsize 2
