# %%
import openpyxl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/features_classes_sorted.csv')
df.head()
# Out:
#                 name  retrieval  appraisal  extraction  output  admin  access  \
# 0  Giotto Compliance          5          6           4       3      6       3
# 1   Nested Knowledge          5          5           2       5      6       4
# 2        DistillerSR          5          6           3       4      6       2
# 3  EPPI-Reviewer Web          4          6           4       3      5       3
# 4          LitStream          2          5           3       3      6       4
#
#    total_count
# 0           27
# 1           27
# 2           26
# 3           25
# 4           23

# %%
del df['total_count']
df.head()
# Out:
#                 name  retrieval  appraisal  extraction  output  admin  access
# 0  Giotto Compliance          5          6           4       3      6       3
# 1   Nested Knowledge          5          5           2       5      6       4
# 2        DistillerSR          5          6           3       4      6       2
# 3  EPPI-Reviewer Web          4          6           4       3      5       3
# 4          LitStream          2          5           3       3      6       4

# %% [markdown]
# ## Make a stacked bar chat
